# %% [markdown]
# ## Update gamelist.xml files
#
# Use the dataset to update gamelist.xml files

# %%
import pandas as pd
import os
from utils.update_gamelist import update_platform_gamelist

# %%
game_df = pd.read_pickle('cleaned_df.pkl')

# %%
# ============================================================
# BULK PROCESSING: Run pipeline on multiple platforms
# ============================================================

# get folder names from lists
lists_folder = "lists"


# Select specific platforms to process (or use list(platform_mappings.keys()) for all)
# platforms_to_process = ["nes", "snes", "genesis", "psx"]
platforms_to_process = [f for f in os.listdir(lists_folder) if os.path.isdir(os.path.join(lists_folder, f))]

print(f"\n{'='*70}")
print(f"PROCESSING {len(platforms_to_process)} PLATFORMS")
print(f"{'='*70}\n")

results_summary = []

for platform_abbrev in platforms_to_process:
    result = update_platform_gamelist(
        platform_abbrev=platform_abbrev,
        game_df=game_df,
        lists_base_path="lists",
        threshold=80,
        verbose=False  # Set to True to see details for each platform
    )
    
    if result['success']:
        results_summary.append({
            'Platform': result['platform_name'],
            'Total Games': result['inventory_count'],
            'Matched': result['matched_count'],
            'Match Rate (%)': f"{result['match_rate']*100:.1f}%",
            'Output': result['xml_output']
        })
        print(f"✓ {result['platform_name']:30s} | {result['matched_count']:4d}/{result['inventory_count']:4d} | {result['match_rate']*100:5.1f}%")
    else:
        print(f"✗ {platform_abbrev:30s} | Error: {result.get('error', 'Unknown')}")

# Display summary table
print(f"\n{'='*70}")
if results_summary:
    summary_df = pd.DataFrame(results_summary)
    print(summary_df.to_string(index=False))
else:
    print("No successful results to summarize")
# Out:
# ======================================================================
# PROCESSING 40 PLATFORMS
# ======================================================================
#
# ✓ Nintendo 64                    |  217/ 217 | 100.0%
# ✓ Sinclair ZX Spectrum           |    7/   7 | 100.0%
# ✓ Sega Dreamcast                 |   10/  10 | 100.0%
# ✓ Sony Playstation               |  265/ 265 | 100.0%
# ✓ Microsoft MSX                  |  564/ 564 | 100.0%
# ✓ Microsoft Xbox                 |    0/   0 |   0.0%
# ✓ MS-DOS                         |  178/ 178 | 100.0%
# ✓ Commodore 64                   |   29/  29 | 100.0%
# ✓ Sony Playstation 2             |   67/  67 | 100.0%
# ✓ Nintendo Game Boy Color        |  548/ 548 | 100.0%
# ✓ Nintendo Game Boy Advance      | 1204/1204 | 100.0%
# ✓ NEC TurboGrafx-16              |  574/ 574 | 100.0%
# ✓ MS-DOS                         |    6/   6 | 100.0%
# ✓ SNK Neo Geo                    |  189/ 189 | 100.0%
# ✓ Sega Game Gear                 |  263/ 263 | 100.0%
# ✓ Nintendo DS                    |   75/  75 | 100.0%
# ✓ Super Nintendo Entertainment System |  976/ 976 | 100.0%
# ✓ Arcade                         |  842/ 842 | 100.0%
# ✓ NEC PC Engine                  |  290/ 290 | 100.0%
# ✓ ScummVM Game Engine            |   20/  20 | 100.0%
# ✓ Arcade                         | 1928/1928 | 100.0%
# ✓ Sega Genesis                   | 1024/1024 | 100.0%
# ✓ SNK Neo Geo Pocket Color       |   81/  81 | 100.0%
# ✓ Nintendo Entertainment System  | 1947/1948 |  99.9%
# ✓ Nintendo Game Boy              |  493/ 493 | 100.0%
# ✓ Bandai WonderSwan              |    0/   0 |   0.0%
# ✓ Sega Master System             |  361/ 361 | 100.0%
# ✓ Sega CD                        |   29/  29 | 100.0%
# ✓ Commodore Amiga                |  154/ 154 | 100.0%
# ✓ Sega Saturn                    |    6/   6 | 100.0%
# ✓ Sony Playstation Portable      |   32/  32 | 100.0%
# ✓ SNK Neo Geo Pocket             |    0/   0 |   0.0%
# ✓ Super Nintendo Entertainment System | 1472/1472 | 100.0%
# ✓ NEC PC Engine CD               |   25/  25 | 100.0%
# ✓ Atari 2600                     |   28/  28 | 100.0%
# ✓ Nintendo Wii                   |    6/   6 | 100.0%
# ✓ Sega Mega Drive                |  954/ 954 | 100.0%
# ✓ Nintendo Entertainment System  | 1183/1184 |  99.9%
# ✓ Nintendo GameCube              |   21/  21 | 100.0%
# ✓ Arcade                         |  188/ 188 | 100.0%
