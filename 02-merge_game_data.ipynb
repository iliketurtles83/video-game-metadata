# %% [markdown]
# ## Merge game databases

# %% [markdown]
# ### Steps
# - pick a main dataset
# - rename columns
# - for each added dataset
#     - rename columns
#     - rename platforms
#     - check column values for anomalies
#     - merge dataset to main
#     - join columns using priority functions

# %%
import pandas as pd
import numpy as np
from utils.merge_pipeline import SourceConfig, run_merge_pipeline
from utils.resolvers import resolver as merge_resolver

# %%
# Canonical schema used by the merge pipeline
default_columns = [
    'name',
    'filename',
    'summary',
    'platform',
    'release_date',
    'release_year',
    'genres',
    'developer',
    'publisher',
    'players',
    'cooperative',
    'rating',
    'user_rating',
]

key_columns = ['name', 'platform']

# %% [markdown]
# ### Launchbox
# Lets choose the Launchbox dataset as our main to which we will merge other datasets

# %%
launchbox = pd.read_csv('csv/launchbox.csv', low_memory=False)
launchbox.columns
# Out:
# Index(['N°', 'DatabaseID', 'Name', 'ReleaseYear', 'Overview', 'MaxPlayers',
#        'ReleaseType', 'Cooperative', 'VideoURL', 'CommunityRating', 'Platform',
#        'ESRB', 'CommunityRatingCount', 'Genres', 'Developer', 'Publisher',
#        'WikipediaURL', 'AlternateName_Australia', 'AlternateName_Brazil',
#        'AlternateName_China', 'AlternateName_Europe', 'AlternateName_France',
#        'AlternateName_Germany', 'AlternateName_Japan', 'AlternateName_Korea',
#        'AlternateName_NorthAmerica', 'AlternateName_Spain',
#        'AlternateName_UnitedStates', 'AlternateName_World'],
#       dtype='object')

# %%
launchbox['Platform'].unique()
# Out:
# array(['3DO Interactive Multiplayer', 'Amstrad CPC', 'Android',
#        'Aamber Pegasus', 'Acorn Archimedes', 'Acorn Atom',
#        'Acorn Electron', 'Amstrad GX4000', 'Apple II', 'Arcade',
#        'APF Imagination Machine', 'Apogee BK-01', 'Apple IIGS',
#        'Apple iOS', 'Apple Mac OS', 'Atari 2600', 'Atari 5200',
#        'Atari 800', 'Atari 7800', 'Atari Jaguar', 'Atari ST',
#        'Atari Jaguar CD', 'Atari Lynx', 'BBC Microcomputer System',
#        'ColecoVision', 'Commodore 128', 'Commodore 64', 'Atari XEGS',
#        'Bally Astrocade', 'Bandai Super Vision 8000', 'Camputers Lynx',
#        'Casio Loopy', 'Casio PV-1000', 'Coleco ADAM', 'Commodore Amiga',
#        'Commodore Amiga CD32', 'Commodore CDTV', 'Commodore MAX Machine',
#        'Commodore PET', 'Commodore VIC-20', 'Epoch Super Cassette Vision',
#        'Exelvision EXL 100', 'Fujitsu FM Towns Marty', 'Microsoft MSX',
#        'Commodore Plus 4', 'Dragon 32/64', 'EACA EG2000 Colour Genie',
#        'Elektronika BK', 'Emerson Arcadia 2001', 'Enterprise',
#        'Entex Adventure Vision', 'Epoch Game Pocket Computer',
#        'Exidy Sorcerer', 'Fairchild Channel F', 'Fujitsu FM-7',
#        'Funtech Super Acan', 'Game Wave Family Entertainment System',
#        'GamePark GP32', 'GameWave', 'GCE Vectrex', 'Hartung Game Master',
#        'Hector HRX', 'Interton VC 4000', 'Jupiter Ace', 'Linux',
#        'Magnavox Odyssey', 'Magnavox Odyssey 2',
#        'Matra and Hachette Alice', 'Mattel Aquarius', 'Mattel HyperScan',
#        'Mattel Intellivision', 'Mega Duck', 'Memotech MTX512',
#        'Microsoft Xbox', 'Microsoft Xbox 360', 'Microsoft MSX2',
#        'Microsoft MSX2+', 'Microsoft Xbox One', 'MS-DOS',
#        'Microsoft Xbox Series X/S', 'NEC PC-8801', 'NEC PC-9801', 'MUGEN',
#        'Namco System 22', 'NEC PC-FX', 'NEC TurboGrafx-16',
#        'NEC TurboGrafx-CD', 'Nintendo 3DS', 'Nintendo 64',
#        'Nintendo 64DD', 'Nintendo DS', 'Nintendo Entertainment System',
#        'Nintendo Famicom Disk System', 'Nintendo Game Boy',
#        'Nintendo Game Boy Advance', 'Nintendo Game Boy Color',
#        'Nintendo GameCube', 'Nintendo Game & Watch', 'Nintendo Switch',
#        'Nintendo Pokemon Mini', 'Nintendo Satellaview', 'Nintendo Wii',
#        'Nintendo Wii U', 'OpenBOR', 'Nintendo Virtual Boy',
#        'Nokia N-Gage', 'Nuon', 'Oric Atmos', 'Othello Multivision',
#        'Ouya', 'PC Engine SuperGrafx', 'Philips CD-i', 'Pinball',
#        'ScummVM', 'Sega CD 32X', 'Sega Dreamcast', 'Sega Dreamcast VMU',
#        'Sega Game Gear', 'Philips VG 5000', 'Philips Videopac+', 'PICO-8',
#        'RCA Studio II', 'SAM Coupé', 'Sammy Atomiswave', 'Sega 32X',
#        'Sega CD', 'Sega Genesis', 'Sega Master System', 'Sega Pico',
#        'Sega Saturn', 'Sega Hikaru', 'Sega Model 1', 'Sega Model 2',
#        'Sega Model 3', 'Sega Naomi', 'Sega Naomi 2', 'Sega SC-3000',
#        'Sega SG-1000', 'Sharp X1', 'Sharp X68000', 'Sinclair ZX Spectrum',
#        'Sega ST-V', 'Sega System 16', 'Sega System 32', 'Sega Triforce',
#        'Sharp MZ-2500', 'SNK Neo Geo AES', 'Sony Playstation',
#        'Sinclair ZX-81', 'SNK Neo Geo CD', 'SNK Neo Geo MVS',
#        'SNK Neo Geo Pocket', 'SNK Neo Geo Pocket Color',
#        'Sony Playstation 2', 'Sony Playstation 3', 'Sony Playstation 4',
#        'Sony Playstation 5', 'Sony Playstation Vita', 'Sony PSP',
#        'Sony PocketStation', 'Sony PSP Minis',
#        'Super Nintendo Entertainment System', 'Windows', 'Sord M5',
#        'Spectravideo', 'Taito Type X', 'Tandy TRS-80', 'Tapwave Zodiac',
#        'Texas Instruments TI 99/4A', 'Tiger Game.com', 'Tomy Tutor',
#        'TRS-80 Color Computer', 'Vector-06C', 'VTech CreatiVision',
#        'VTech Socrates', 'VTech V.Smile', 'Watara Supervision',
#        'Web Browser', 'Windows 3.X', 'WonderSwan', 'WonderSwan Color',
#        'WoW Action Max', 'XaviXPORT', 'ZiNc'], dtype=object)

# %%
launchbox.head()
# Out:
#         N°  ...                        AlternateName_World
# 0  6658890  ...                                        NaN
# 1  6658891  ...                                        NaN
# 2  6658892  ...                                        NaN
# 3  6658893  ...  3DO de Shiru Miru Asobu - Nakajima Miyuki
# 4  6658894  ...                                        NaN
#
# [5 rows x 29 columns]

# %%
# Step 1: Define the main (first) dataset config
main_config = SourceConfig(
    name='launchbox',
    path='csv/launchbox.csv',
    keep_columns=[
        'Name', 'ReleaseYear', 'Overview', 'MaxPlayers', 'Cooperative',
        'Platform', 'CommunityRating', 'Genres', 'Developer', 'Publisher'
    ],
    rename_map={
        'Name': 'name',
        'ReleaseYear': 'release_year',
        'Overview': 'summary',
        'MaxPlayers': 'players',
        'Cooperative': 'cooperative',
        'Platform': 'platform',
        'CommunityRating': 'user_rating',
        'Genres': 'genres',
        'Developer': 'developer',
        'Publisher': 'publisher'
    },
    transforms={
        'release_year': lambda s: pd.to_numeric(s, errors='coerce'),
        'user_rating': lambda s: pd.to_numeric(s, errors='coerce') * 2,
    },
    dedupe_sort=['name', 'platform', 'summary'],
    dedupe_subset=['name', 'platform']
 )

# %% [markdown]
# ### Merge with all_games

# %%
all_games = pd.read_csv('csv/all_games.csv')
all_games.columns
# Out:
# Index(['name', 'platform', 'release_date', 'summary', 'meta_score',
#        'user_review'],
#       dtype='object')

# %%
print(all_games['platform'].value_counts())
# Out:
# platform
# PC                  4864
# PlayStation 4       2056
# Xbox 360            1644
# PlayStation 2       1414
# Switch              1399
# PlayStation 3       1256
# Xbox One            1179
# Xbox                 789
# DS                   720
# Wii                  655
# PSP                  512
# GameCube             448
# Game Boy Advance     438
# 3DS                  396
# PlayStation Vita     257
# PlayStation          187
# Wii U                184
# Dreamcast            125
# PlayStation 5        124
# Xbox Series X         77
# Nintendo 64           71
# Stadia                 5
# Name: count, dtype: int64

# %%
all_games.head()
# Out:
#                                    name        platform  ... meta_score user_review
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64  ...         99         9.1
# 1              Tony Hawk's Pro Skater 2     PlayStation  ...         98         7.4
# 2                   Grand Theft Auto IV   PlayStation 3  ...         98         7.7
# 3                           SoulCalibur       Dreamcast  ...         98         8.4
# 4                   Grand Theft Auto IV        Xbox 360  ...         98         7.9
#
# [5 rows x 6 columns]

# %%
# Step 2: Prepare all_games dataset
all_games_platform_map = {
    'PlayStation': 'Sony Playstation',
    'PlayStation 2': 'Sony Playstation 2',
    'PlayStation 3': 'Sony Playstation 3',
    'PlayStation 4': 'Sony Playstation 4',
    'PlayStation 5': 'Sony Playstation 5',
    'PlayStation Vita': 'Sony Playstation Vita',
    'PSP': 'Sony PSP',
    'Dreamcast': 'Sega Dreamcast VMU',
    'Xbox 360': 'Microsoft Xbox 360',
    'Xbox': 'Microsoft Xbox',
    'Xbox One': 'Microsoft Xbox One',
    'Xbox Series X': 'Microsoft Xbox Series X',
    'Wii': 'Nintendo Wii',
    'Wii U': 'Nintendo Wii U',
    'Switch': 'Nintendo Switch',
    'GameCube': 'Nintendo GameCube',
    'Game Boy Advance': 'Nintendo Game Boy Advance',
    '3DS': 'Nintendo 3DS',
    'DS': 'Nintendo DS',
    'Stadia': 'Google Stadia',
    'PC': 'Windows'
}

all_games_config = SourceConfig(
    name='all_games',
    path='csv/all_games.csv',
    rename_map={
        'meta_score': 'rating',
        'user_review': 'user_rating'
    },
    replace_map={'tbd': np.nan},
    platform_map=all_games_platform_map,
    transforms={
        'platform': lambda s: s.astype(str).str.strip(),
        'release_date': lambda s: pd.to_datetime(s, errors='coerce'),
        'rating': lambda s: pd.to_numeric(s, errors='coerce'),
        'user_rating': lambda s: pd.to_numeric(s, errors='coerce')
    },
    dropna_subset=['name', 'platform'],
    dedupe_sort=['name', 'platform', 'user_rating'],
    dedupe_subset=['name', 'platform']
)

# %% [markdown]
# ### GameTDB

# %%
gametdb = pd.read_csv('csv/games_on_gametdb.csv')
print(gametdb.columns)
gametdb['gametdb_platform'].unique()
# Out:
# Index(['N°', 'gametdb_id', 'gametdb_type', 'gametdb_region',
#        'gametdb_languages', 'gametdb_title_de', 'gametdb_title_en',
#        'gametdb_title_es', 'gametdb_title_fr', 'gametdb_title_it',
#        'gametdb_title_ja', 'gametdb_title_ko', 'gametdb_title_nl',
#        'gametdb_title_pt', 'gametdb_title_ru', 'gametdb_synopsis_de',
#        'gametdb_synopsis_en', 'gametdb_synopsis_es', 'gametdb_synopsis_fr',
#        'gametdb_synopsis_it', 'gametdb_synopsis_ja', 'gametdb_synopsis_ko',
#        'gametdb_synopsis_nl', 'gametdb_synopsis_pt', 'gametdb_synopsis_ru',
#        'gametdb_developer', 'gametdb_publisher', 'gametdb_date',
#        'gametdb_players', 'gametdb_genre', 'gametdb_rom',
#        'gametdb_rom_sans_ext', 'gametdb_platform', 'gametdb_title_cn',
#        'gametdb_title_tw', 'gametdb_synopsis_cn', 'gametdb_synopsis_tw',
#        'gametdb_rom_cleaned'],
#       dtype='object')
# array(['3DS', 'DS', 'PS3', 'Switch', 'Wii', 'WiiU'], dtype=object)

# %%
gametdb.head()
# Out:
#         N°  ...                 gametdb_rom_cleaned
# 0  1108862  ...  Bokujou Monogatari Futago no Mura+
# 1  1108863  ...                   Pokémon Ultra Sun
# 2  1108864  ...                   Pokémon Ultra Sun
# 3  1108865  ...                   Pokémon Ultra Sun
# 4  1108866  ...                   Pokémon Ultra Sun
#
# [5 rows x 38 columns]

# %%
gametdb_platform_map = {
    '3DS': 'Nintendo 3DS',
    'DS': 'Nintendo DS',
    'PS3': 'Sony Playstation 3',
    'Switch': 'Nintendo Switch',
    'Wii': 'Nintendo Wii',
    'WiiU': 'Nintendo Wii U'
}

gametdb_config = SourceConfig(
    name='gametdb',
    path='csv/games_on_gametdb.csv',
    keep_columns=[
        'gametdb_platform', 'gametdb_title_en', 'gametdb_synopsis_en',
        'gametdb_developer', 'gametdb_publisher', 'gametdb_date',
        'gametdb_players', 'gametdb_genre'
    ],
    rename_map={
        'gametdb_platform': 'platform',
        'gametdb_title_en': 'name',
        'gametdb_synopsis_en': 'summary',
        'gametdb_developer': 'developer',
        'gametdb_publisher': 'publisher',
        'gametdb_date': 'release_date',
        'gametdb_players': 'players',
        'gametdb_genre': 'genres'
    },
    platform_map=gametdb_platform_map,
    transforms={
        'release_date': lambda s: pd.to_datetime(s, errors='coerce')
    },
    dropna_subset=['name'],
    dedupe_sort=['name', 'platform', 'summary', 'developer', 'publisher'],
    dedupe_subset=['name', 'platform']
)

print('gametdb_config ready for run_merge_pipeline')
# Out:
# gametdb_config ready for run_merge_pipeline

# %% [markdown]
# ### DAT DOS dataset

# %%
dat_dos = pd.read_csv('csv/dat_database_dos.csv')
dat_dos.columns
# Out:
# Index(['ID', 'gametitle_mame', 'developer_mame', 'year_mame', 'genre_mame',
#        'description_mame', 'publisher_mame'],
#       dtype='object')

# %%
dat_dos.isnull().sum()
# Out:
# ID                   0
# gametitle_mame       0
# developer_mame       3
# year_mame            0
# genre_mame           1
# description_mame    12
# publisher_mame      31
# dtype: int64

# %%
dat_dos_config = SourceConfig(
    name='dat_dos',
    path='csv/dat_database_dos.csv',
    keep_columns=['gametitle_mame', 'developer_mame', 'year_mame', 'genre_mame', 
                  'description_mame', 'publisher_mame'
    ],
    rename_map={
        'gametitle_mame': 'name', 
        'developer_mame': 'developer', 
        'year_mame': 'release_date', 
        'genre_mame': 'genres',
        'description_mame': 'summary',
        'publisher_mame': 'publisher'
    },
    constants={'platform': 'MS-DOS'},
    replace_map={'-': np.nan},
    transforms={
        'release_date': lambda s: pd.to_datetime(s, errors='coerce')
    },
    dropna_subset=['name'],
    dedupe_sort=['name', 'platform', 'summary'],
    dedupe_subset=['name', 'platform']
)

print('dat_dos_config ready for run_merge_pipeline')
# Out:
# dat_dos_config ready for run_merge_pipeline

# %% [markdown]
# ## DAT MAME

# %%
dat_mame = pd.read_csv('csv/dat_database_mame.csv', low_memory=False)
dat_mame.columns
# Out:
# Index(['ID', 'systemname_mame', 'gametitle_mame', 'filename_mame',
#        'cloneof_mame', 'manufacturer_mame', 'year_mame', 'genre_mame'],
#       dtype='object')

# %%
dat_mame.head()
# Out:
#        ID                systemname_mame  ...   year_mame genre_mame
# 0  355065  advmame 0.94-RetroPie-260.dat  ...  1980/01/01        NaN
# 1  355066  advmame 0.94-RetroPie-260.dat  ...  1980/01/01        NaN
# 2  355067  advmame 0.94-RetroPie-260.dat  ...  1980/01/01        NaN
# 3  355068  advmame 0.94-RetroPie-260.dat  ...  1980/01/01        NaN
# 4  355069  advmame 0.94-RetroPie-260.dat  ...  1980/01/01        NaN
#
# [5 rows x 8 columns]

# %%
dat_mame['systemname_mame'].value_counts()
# Out:
# systemname_mame
# MAME 0.260.dat                                   46199
# MAME 0.240 (Arcade).dat                          36604
# mame2016 - MAME 0.174 Arcade XML.dat             32071
# mame2015 - MAME 0.160 XML.dat                    30906
# Mame 0.239.xml                                   29027
# Mame 0.270.xml                                   17538
# Mame 0.267.xml                                   12904
# mame2010.xml                                      8833
# FinalBurn_Neo_ClrMame_Pro_XML_Arcade_only.dat     6998
# advmame 12-106.dat                                6166
# advmame 0.94-RetroPie-260.dat                     5563
# mame2003-plus.xml                                 5219
# mame2003.xml                                      4726
# vgmplay.xml                                       3645
# FB Alpha 2012 v0.2.97.30.dat                      3369
# mame2000 mame4all - MAME 0.37b5.dat               2241
# FB Alpha v0.2.96.71 working_roms.dat               684
# Name: count, dtype: int64

# %%
# looks like duplicates for each version of MAME. Let's use the one that says Arcade.
dat_mame_subset = dat_mame[dat_mame['systemname_mame'] == 'MAME 0.240 (Arcade).dat']

# %%
dat_mame_subset.head()
# Out:
#            ID          systemname_mame  ...   year_mame genre_mame
# 51807  406872  MAME 0.240 (Arcade).dat  ...  1981/01/01        NaN
# 51808  406873  MAME 0.240 (Arcade).dat  ...  2006/01/01        NaN
# 51809  406874  MAME 0.240 (Arcade).dat  ...  1983/01/01        NaN
# 51810  406875  MAME 0.240 (Arcade).dat  ...  1985/01/01        NaN
# 51811  406876  MAME 0.240 (Arcade).dat  ...  1983/01/01        NaN
#
# [5 rows x 8 columns]

# %%
# DAT MAME sourceconfig
dat_mame_config = SourceConfig(
    name='dat_mame',
    path='csv/dat_database_mame.csv',
    read_csv_kwargs={'low_memory': False},
    loader=lambda: (
        pd.read_csv('csv/dat_database_mame.csv', low_memory=False)
        .query("systemname_mame == 'MAME 0.240 (Arcade).dat'")
        [['gametitle_mame', 'filename_mame', 'manufacturer_mame', 'year_mame', 'genre_mame']]
    ),
    rename_map={
        'gametitle_mame': 'name',
        'filename_mame': 'filename',
        'manufacturer_mame': 'developer',
        'year_mame': 'release_date',
        'genre_mame': 'genres'
    },
    constants={'platform': 'Arcade'},
    transforms={
        'release_date': lambda s: pd.to_datetime(s, errors='coerce')
    },
    dropna_subset=['name'],
    dedupe_sort=['name', 'platform', 'developer', 'release_date', 'genres'],
    dedupe_subset=['name', 'platform']
)

# %% [markdown]
# ### Recalbox

# %%
recalbox = pd.read_csv('csv/recalbox_gamelist.csv')
recalbox.columns
# Out:
# Index(['numauto_rom', 'nomjeu_rom', 'fichier_rom', 'description_rom',
#        'image_rom', 'rating_rom', 'annee_rom', 'developer_rom',
#        'publisher_rom', 'genre_rom', 'players_rom', 'cache_rom', 'favoris_rom',
#        'boxart_rom', 'screenshot_rom', 'wheel_rom', 'video_rom', 'mix_rom',
#        'playcount_rom', 'lastplayed_rom', 'md5_rom', 'core_rom',
#        'emulator_rom', 'cartridge_rom', 'hash_rom', 'manual_rom', 'region_rom',
#        'thumbnail_rom', 'marquee_rom', 'genreid_rom', 'fanart_rom', 'map_rom',
#        'titleshot_rom', 'lang_rom', 'gameid_rom', 'kid_rom', 'adult_rom',
#        'arcadesystemname_rom', 'gametime_rom', 'boxback_rom', 'temporary_rom',
#        'bezel_rom', 'ratio_rom', 'rotation_rom', 'extra1_rom', 'famille_rom',
#        'mode_rom'],
#       dtype='object')

# %%
recalbox.head()
# Out:
#    numauto_rom                               nomjeu_rom  ... famille_rom mode_rom
# 0        33308                 4-in-1 Fun Pak Volume II  ...         NaN      NaN
# 1        33310                        The Addams Family  ...         NaN      NaN
# 2        33312  Adventure Island II: Aliens in Paradise  ...         NaN      NaN
# 3        33314             The Adventures of Star Saver  ...         NaN      NaN
# 4        33315                                 Aerostar  ...         NaN      NaN
#
# [5 rows x 47 columns]

# %%
recalbox['genre_rom'].unique()
# Out:
# array(['Variados-Jogo de tabuleiro', 'Ação', 'Ação-Plataforma',
#        "Shoot'em Up-Ação", 'Quebra-Cabeças', 'Esporte', 'Quebra-cabeças',
#        "Shoot'em Up", 'Ação-Quebra-Cabeças', 'Aventura', 'Plataforma',
#        'Luta-Ação', 'Ação-Estratégia', 'Briga De Rua-Ação',
#        'Plataforma-Ação', 'Quebra-Cabeças-Ação',
#        'Quebra-Cabeças-Jogo De Tabuleiro', 'Variados',
#        'Quebra-cabeças-Estratégia', "Quebra-Cabeças-Ação-Shoot'em Up",
#        'Estratégia', 'Simulação-Aventura', 'Quebra-cabeças-Ação',
#        'Ação-Aventura', 'Corrida, Pilotagem', 'Action, Platform',
#        'Briga De Rua', 'Plataforma / Combate Com Rolagem-Plataforma',
#        'Plataforma-Corrida, Pilotagem-Ação', 'Puzzle',
#        'Esporte / Futebol-Esporte', nan, 'Simulação', 'Racing, Driving',
#        'Esporte-Simulação',
#        'Fighting / 2D, Fighting, Platform / Fighter Scrolling, Platform',
#        'Jogos De Rpg', 'Jogos de RPG', 'Esporte-Ação', 'Tiro-Ação',
#        'Plataforma / Combate Com Rolagem-Ação-Plataforma',
#        'Racing, Driving, Shooter / Run and Gun, Shooter',
#        "Ação-Shoot'em Up / Horizontal-Shoot'em Up", 'Luta',
#        'Cassino / Cartas-Cassino', 'Compilation',
#        'Esporte / Basquete-Esporte', 'Quiz', 'Ação / Aventura-Ação',
#        'Esporte / Tênis-Esporte', 'Platform', 'Sports / Baseball, Sports',
#        'Role Playing Game', 'Action / Labyrinth, Action',
#        'Sports / Football (American), Sports', 'Briga de rua-Ação',
#        'Esporte-Corrida, Pilotagem-Ação', 'Variados-Ação',
#        'Jogos De Rpg-Ação / Aventura-Ação', 'Sports / Basketball, Sports',
#        'Esporte / Futebol Americano-Esporte', 'Esporte / Golfe-Esporte',
#        'Quebra-cabeças-Estratégia-Ação', 'Sports / Hockey, Sports',
#        'Platform, Puzzle', 'Corrida, Pilotagem-Ação', 'Playing cards',
#        'Variados-Esporte-Simulação', 'Puzzle, Strategy', 'Pinball',
#        'Ação-Pinball', "Action, Shoot'em Up", 'Ação-Quebra-cabeças',
#        'Jogos De Rpg-Ação',
#        "Shoot'em Up, Action, Shoot'em Up / Horizontal",
#        'Educacional-Ação',
#        'Sports / Baseball, Sports / Football (American), Sports',
#        'Estratégia-Plataforma-Quebra-Cabeças', 'Casino / Cards, Casino',
#        'Fighting', 'Corrida Em 3ª Pessoa-Corrida, Pilotagem',
#        'Tiro Com Acessórios', "Shoot'em Up / Horizontal-Shoot'em Up",
#        'Action, Platform / Run & Jump, Platform', 'Action, Puzzle',
#        'Esporte-Esporte / Tênis',
#        "Shoot'em Up / Vertical, Shoot'em Up, Shooter",
#        'Aventura-Plataforma', 'Simulation',
#        'Sports / Football (Soccer), Sports',
#        'Esporte-Esporte / Luta Livre', 'Variados-Simulação',
#        'Variados-Pinball-Ação', 'Variados-Jogo De Tabuleiro',
#        'Variados-Estratégia-Quebra-Cabeças', 'Variados-Ação-Pinball',
#        'Various / Action', 'Action / Various', 'Simulação-Ação',
#        "Shoot'em Up-Plataforma", "Shoot'em Up-Jogos De Rpg",
#        "Shoot'em Up-Esporte", 'Quebra-Cabeças-Plataforma',
#        'Quebra-Cabeças-Jogos De Rpg', 'Quebra-Cabeças-Estratégia-Ação',
#        'Quebra-Cabeças-Estratégia',
#        'Plataforma / Combate com rolagem-Plataforma', 'Luta-Esporte',
#        'Jogos De Rpg-Simulação', 'Jogos De Rpg-Corrida, Pilotagem-Ação',
#        'Estratégia-Quebra-Cabeças', 'Estratégia-Quebra-cabeças',
#        'Esporte-Quebra-Cabeças', 'Esporte / Boxe-Esporte',
#        'Esporte-Estratégia-Quebra-Cabeças', 'Esporte-Estratégia-Ação',
#        'Corrida, Pilotagem-Jogos De Rpg',
#        'Corrida, Pilotagem-Estratégia-Quebra-Cabeças',
#        "Briga De Rua-Shoot'em Up-Ação",
#        'Ação-Plataforma / Corre E Pula-Plataforma',
#        'Ação-Plataforma / Corre E Pula Com Rolagem-Plataforma',
#        'Ação-Jogos De Rpg', 'Briga de rua', "Ação-Shoot'em Up",
#        'Action, Various, Role Playing Game', 'Action, Action / Labyrinth',
#        "Shoot'em Up / Horizontal, Action, Shooter / Run and Gun, Shoot'em Up, Shooter",
#        'Platform / Run & Jump, Platform', 'Puzzle / Fall, Puzzle',
#        "Action, Shooter, Shoot'em Up", "Beat'em Up",
#        'Action, Platform / Shooter Scrolling, Platform', 'Various',
#        'Sports / Volleyball, Sports', 'Sports / Boxing, Sports',
#        "Action, Shoot'em Up / Horizontal, Shoot'em Up",
#        'Action, Casual Game', 'Action',
#        "Shoot'em Up, Shoot'em Up / Horizontal", 'Sports / Golf, Sports',
#        'Action, Puzzle, Platform',
#        'Platform / Fighter Scrolling, Platform',
#        'Sports, Sports / Handball',
#        'Sports / Multisports, Sports, Sports / Extreme',
#        'Strategy, Action', 'Fishing, Simulation, Hunting and Fishing',
#        'Puzzle, Puzzle / Fall', 'Puzzle / Fall, Action, Puzzle', 'Sports',
#        'Shooter, Shooter / Run and Gun',
#        "Shoot'em Up / Vertical, Shoot'em Up",
#        'Fighting, Sports / Wrestling, Sports', 'Sports / Bowling, Sports'],
#       dtype=object)

# %%
def extract_max_players(players):
    if players is None:
        return None
    if '-' in str(players):
        return int(players.split('-')[-1])
    else:
        return int(players)

recalbox_config = SourceConfig(
    name='recalbox',
    path='csv/recalbox_gamelist.csv',
    keep_columns=[
        'nomjeu_rom', 'fichier_rom', 'description_rom', 'rating_rom',
        'annee_rom', 'developer_rom', 'publisher_rom', 'genre_rom', 'players_rom'
    ],
    rename_map={
        'nomjeu_rom': 'name',
        'fichier_rom': 'filename',
        'description_rom': 'summary',
        'rating_rom': 'user_rating',
        'annee_rom': 'release_date',
        'developer_rom': 'developer',
        'publisher_rom': 'publisher',
        'genre_rom': 'genres',
        'players_rom': 'players'
    },
    constants={'platform': 'Nintendo Entertainment System'},
    replace_map={np.nan: None},
    transforms={
        'release_date': lambda s: pd.to_datetime(s, errors='coerce'),
        'user_rating': lambda s: pd.to_numeric(s, errors='coerce') * 10,
        'players': lambda s: s.apply(extract_max_players)
    },
    dedupe_subset=['name', 'platform']
)

# %% [markdown]
# ### The final merge

# %%
# Step 3: Merge all_games into launchbox
# Build the source_configs list with all sources to merge
source_configs = [all_games_config, gametdb_config, dat_dos_config, dat_mame_config, recalbox_config]

# Call run_merge_pipeline() to orchestrate the merge
merged_df = run_merge_pipeline(
    main_config=main_config,
    source_configs=source_configs,
    target_columns=default_columns,
    key_columns=key_columns,
    resolver_map=merge_resolver
)

print(f'Final merged rows: {len(merged_df)}')
print(f'Unique (name, platform) keys: {merged_df.duplicated(subset=key_columns).sum()} duplicates')
merged_df.head()
# Out:
# /home/jack/Projects/video-game-metadata/utils/merge_pipeline.py:54: DtypeWarning: Columns (17,18,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   frame = pd.read_csv(config.path, **config.read_csv_kwargs)
# /home/jack/Projects/video-game-metadata/utils/merge_pipeline.py:192: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stacked = pd.concat([main_df, source_df], ignore_index=True, sort=False)
# /home/jack/Projects/video-game-metadata/utils/merge_pipeline.py:192: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stacked = pd.concat([main_df, source_df], ignore_index=True, sort=False)
# /home/jack/Projects/video-game-metadata/utils/merge_pipeline.py:192: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stacked = pd.concat([main_df, source_df], ignore_index=True, sort=False)
# /home/jack/Projects/video-game-metadata/utils/merge_pipeline.py:192: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stacked = pd.concat([main_df, source_df], ignore_index=True, sort=False)
# /home/jack/Projects/video-game-metadata/utils/merge_pipeline.py:192: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stacked = pd.concat([main_df, source_df], ignore_index=True, sort=False)
# Final merged rows: 248969
# Unique (name, platform) keys: 0 duplicates
#                                              name  ... user_rating
# 0    ! That Bastard Is Trying To Steal Our Gold !  ...    8.000000
# 1                                      !!!Ants!!!  ...    5.000000
# 2                                           "300"  ...    6.944444
# 3                                        "8 Ball"  ...    7.250000
# 4  "History in the Making": The First Three Years  ...    6.972222
#
# [5 rows x 13 columns]

# %%
import pickle
with open('merged_df.pkl', 'wb') as f:
    pickle.dump(merged_df, f)
